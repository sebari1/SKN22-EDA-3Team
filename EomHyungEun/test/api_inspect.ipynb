# %%
import requests
import json

ENDPOINT = "https://graphql.anilist.co"

INTROSPECTION_QUERY = """
query {
  __type(name: "Media") {
    name
    fields {
      name
      description
      type {
        kind
        name
        ofType {
          kind
          name
        }
      }
    }
  }
}
"""

resp = requests.post(
    ENDPOINT,
    json={"query": INTROSPECTION_QUERY},
    headers={"Content-Type": "application/json"},
)
print(resp.text)
# Out:
# {"data":{"__type":{"name":"Media","fields":[{"name":"id","description":"The id of the media","type":{"kind":"NON_NULL","name":null,"ofType":{"kind":"SCALAR","name":"Int"}}},{"name":"idMal","description":"The mal id of the media","type":{"kind":"SCALAR","name":"Int","ofType":null}},{"name":"title","description":"The official titles of the media in various languages","type":{"kind":"OBJECT","name":"MediaTitle","ofType":null}},{"name":"type","description":"The type of the media; anime or manga","type":{"kind":"ENUM","name":"MediaType","ofType":null}},{"name":"format","description":"The format the media was released in","type":{"kind":"ENUM","name":"MediaFormat","ofType":null}},{"name":"status","description":"The current releasing status of the media","type":{"kind":"ENUM","name":"MediaStatus","ofType":null}},{"name":"description","description":"Short description of the media's story and characters","type":{"kind":"SCALAR","name":"String","ofType":null}},{"name":"startDate","description":"The first official release date of the media","type":{"kind":"OBJECT","name":"FuzzyDate","ofType":null}},{"name":"endDate","description":"The last official release date of the media","type":{"kind":"OBJECT","name":"FuzzyDate","ofType":null}},{"name":"season","description":"The season the media was initially released in","type":{"kind":"ENUM","name":"MediaSeason","ofType":null}},{"name":"seasonYear","description":"The season year the media was initially released in","type":{"kind":"SCALAR","name":"Int","ofType":null}},{"name":"seasonInt","description":"The year & season the media was initially released in","type":{"kind":"SCALAR","name":"Int","ofType":null}},{"name":"episodes","description":"The amount of episodes the anime has when complete","type":{"kind":"SCALAR","name":"Int","ofType":null}},{"name":"duration","description":"The general length of each anime episode in minutes","type":{"kind":"SCALAR","name":"Int","ofType":null}},{"name":"chapters","description":"The amount of chapters the manga has when complete","type":{"kind":"SCALAR","name":"Int","ofType":null}},{"name":"volumes","description":"The amount of volumes the manga has when complete","type":{"kind":"SCALAR","name":"Int","ofType":null}},{"name":"countryOfOrigin","description":"Where the media was created. (ISO 3166-1 alpha-2)","type":{"kind":"SCALAR","name":"CountryCode","ofType":null}},{"name":"isLicensed","description":"If the media is officially licensed or a self-published doujin release","type":{"kind":"SCALAR","name":"Boolean","ofType":null}},{"name":"source","description":"Source type the media was adapted from.","type":{"kind":"ENUM","name":"MediaSource","ofType":null}},{"name":"hashtag","description":"Official Twitter hashtags for the media","type":{"kind":"SCALAR","name":"String","ofType":null}},{"name":"trailer","description":"Media trailer or advertisement","type":{"kind":"OBJECT","name":"MediaTrailer","ofType":null}},{"name":"updatedAt","description":"When the media's data was last updated","type":{"kind":"SCALAR","name":"Int","ofType":null}},{"name":"coverImage","description":"The cover images of the media","type":{"kind":"OBJECT","name":"MediaCoverImage","ofType":null}},{"name":"bannerImage","description":"The banner image of the media","type":{"kind":"SCALAR","name":"String","ofType":null}},{"name":"genres","description":"The genres of the media","type":{"kind":"LIST","name":null,"ofType":{"kind":"SCALAR","name":"String"}}},{"name":"synonyms","description":"Alternative titles of the media","type":{"kind":"LIST","name":null,"ofType":{"kind":"SCALAR","name":"String"}}},{"name":"averageScore","description":"A weighted average score of all the user's scores of the media","type":{"kind":"SCALAR","name":"Int","ofType":null}},{"name":"meanScore","description":"Mean score of all the user's scores of the media","type":{"kind":"SCALAR","name":"Int","ofType":null}},{"name":"popularity","description":"The number of users with the media on their list","type":{"kind":"SCALAR","na ...

# %%
import requests
import json
from pathlib import Path

ENDPOINT = "https://graphql.anilist.co"

QUERY = """
query ($page: Int!, $perPage: Int!) {
  Page(page: $page, perPage: $perPage) {
    media(
      type: ANIME
      sort: POPULARITY_DESC
      isAdult: false
    ) {
      ...MediaFields
    }
  }
}

fragment MediaFields on Media {
  id
  idMal
  title {
    romaji
    english
    native
    userPreferred
  }
  type
  format
  status
  description
  startDate { year month day }
  endDate { year month day }
  season
  seasonYear
  seasonInt
  episodes
  duration
  chapters
  volumes
  countryOfOrigin
  isLicensed
  source
  hashtag
  trailer {
    id
    site
    thumbnail
  }
  updatedAt
  coverImage {
    extraLarge
    large
    medium
    color
  }
  bannerImage
  genres
  synonyms
  averageScore
  meanScore
  popularity
  isLocked
  trending
  favourites
  tags {
    id
    name
    rank
    isGeneralSpoiler
    isMediaSpoiler
    isAdult
    category
  }
  relations {
    edges {
      relationType
      id
    }
    nodes {
      id
      title {
        romaji
        english
        native
      }
    }
  }
  characters {
    edges {
      role
    }
    nodes {
      id
      name { full native }
      gender
    }
  }
  staff {
    edges { role }
    nodes {
      id
      name { full native }
      primaryOccupations
    }
  }
  studios {
    edges { isMain }
    nodes {
      id
      name
      siteUrl
    }
  }
  isFavourite
  isFavouriteBlocked
  isAdult
  nextAiringEpisode {
    id
    airingAt
    episode
  }
  airingSchedule {
    edges {
      id
      node {
        id
        airingAt
        episode
      }
    }
  }
  trends {
    nodes {
      date
      trending
      averageScore
      popularity
    }
  }
  externalLinks {
    url
    site
    type
  }
  streamingEpisodes {
    title
    thumbnail
    url
    site
  }
  rankings {
    id
    rank
    type
    year
    season
    format
    context
  }
  mediaListEntry {
    id
    status
    score
  }
  reviews {
    nodes {
      id
      summary
      score
    }
  }
  recommendations {
    nodes {
      id
      rating
    }
  }
  stats {
    scoreDistribution { score amount }
    statusDistribution { status amount }
  }
  siteUrl
  autoCreateForumThread
  isRecommendationBlocked
  isReviewBlocked
  modNotes
}
"""

def dump_test_5_json(output_path="anilist_test_5.json"):
    variables = {"page": 1, "perPage": 5}

    resp = requests.post(
        ENDPOINT,
        json={"query": QUERY, "variables": variables},
        headers={"Content-Type": "application/json", "Accept": "application/json"},
    )

    if resp.status_code != 200:
        print("STATUS:", resp.status_code)
        print("ERROR:", resp.text)
        return

    data = resp.json()
    media_list = data["data"]["Page"]["media"]

    Path(output_path).write_text(
        json.dumps(media_list, indent=2, ensure_ascii=False),
        encoding="utf-8",
    )

    print(f"Saved test dataset → {output_path}")


if __name__ == "__main__":
    dump_test_5_json()
# Out:
# Saved test dataset → anilist_test_5.json

# %%
import json
import pandas as pd

pd.set_option("display.max_columns", None)

# 업로드한 JSON 파일 경로
path = "anilist_test_5.json"

# JSON 불러오기
with open(path, "r") as f:
    data = json.load(f)

# data = 리스트 형태 (5개 작품)
rows = []

for m in data:
    row = {
        "id": m.get("id"),
        "idMal": m.get("idMal"),
        "title_romaji": m.get("title", {}).get("romaji"),
        "title_english": m.get("title", {}).get("english"),
        "title_native": m.get("title", {}).get("native"),
        "type": m.get("type"),
        "format": m.get("format"),
        "status": m.get("status"),
        "episodes": m.get("episodes"),
        "duration": m.get("duration"),
        "source": m.get("source"),
        "season": m.get("season"),
        "seasonYear": m.get("seasonYear"),
        "averageScore": m.get("averageScore"),
        "meanScore": m.get("meanScore"),
        "popularity": m.get("popularity"),
        "favourites": m.get("favourites"),
        
        # 날짜 필드 분리
        "start_year": m.get("startDate", {}).get("year"),
        "start_month": m.get("startDate", {}).get("month"),
        "start_day": m.get("startDate", {}).get("day"),
        "end_year": m.get("endDate", {}).get("year"),
        "end_month": m.get("endDate", {}).get("month"),
        "end_day": m.get("endDate", {}).get("day"),
        
        # 리스트 필드들
        "genres": ", ".join(m.get("genres", []) or []),
        "synonyms": ", ".join(m.get("synonyms", []) or []),
        "tags": ", ".join([t["name"] for t in m.get("tags", [])]),
        
        # 스튜디오
        "studios": ", ".join([s["name"] for s in m.get("studios", {}).get("nodes", [])]),
    }
    rows.append(row)

df = pd.DataFrame(rows)
df.head()
# Out:
#        id  idMal           title_romaji                   title_english  \
# 0   16498  16498     Shingeki no Kyojin                 Attack on Titan
# 1  101922  38000       Kimetsu no Yaiba  Demon Slayer: Kimetsu no Yaiba
# 2    1535   1535             DEATH NOTE                      Death Note
# 3  113415  40748         Jujutsu Kaisen                  JUJUTSU KAISEN
# 4   21459  31964  Boku no Hero Academia                My Hero Academia
#
#   title_native   type format    status  episodes  duration source  season  \
# 0        進撃の巨人  ANIME     TV  FINISHED        25        24  MANGA  SPRING
# 1         鬼滅の刃  ANIME     TV  FINISHED        26        24  MANGA  SPRING
# 2   DEATH NOTE  ANIME     TV  FINISHED        37        23  MANGA    FALL
# 3         呪術廻戦  ANIME     TV  FINISHED        24        24  MANGA    FALL
# 4  僕のヒーローアカデミア  ANIME     TV  FINISHED        13        24  MANGA  SPRING
#
#    seasonYear  averageScore  meanScore  popularity  favourites  start_year  \
# 0        2013            85         85      922903       55725        2013
# 1        2019            82         82      876638       42035        2019
# 2        2006            84         84      840282       44144        2006
# 3        2020            84         84      831217       49275        2020
# 4        2016            76         76      777465       20687        2016
#
#    start_month  start_day  end_year  end_month  end_day  \
# 0            4          7      2013          9       28
# 1            4          6      2019          9       28
# 2           10          4      2007          6       27
# 3           10          3      2021          3       27
# 4            4          3      2016          6       26
#
#                                             genres  \
# 0                  Action, Drama, Fantasy, Mystery
# 1  Action, Adventure, Drama, Fantasy, Supernatural
# 2   Mystery, Psychological, Supernatural, Thriller
# 3                      Action, Drama, Supernatural
# 4                        Action, Adventure, Comedy
#
#                                             synonyms  \
# 0  SnK, AoT, Ataque a los Titanes, Ataque dos Tit...
# 1  KnY, Kimetsu no Yaiba: Kyoudai no Kizuna, Demo...
# 2  デスノート, 死亡笔记, מחברת המוות, Notatnik śmierci, Ca...
# 3  JJK, Sorcery Fight, 咒术回战, 주술회전, มหาเวทย์ผนึกมา...
# 4  BNHA, MHA, 나의 히어로 아카데미아 1기, 나히아 1기, אקדמיית הג...
#
#                                                 tags  \
# 0  Kaiju, Revenge, Military, Tragedy, Post-Apocal...
# 1  Demons, Shounen, Swordplay, Male Protagonist, ...
# 2  Crime, Detective, Anti-Hero, Male Protagonist,...
# 3  Urban Fantasy, Shounen, Youkai, Super Power, C...
# 4  Super Power, Superhero, Shounen, Primarily Tee...
#
#                                              studios
# 0  WIT STUDIO, Pony Canyon, Kodansha, Production ...
# 1  ufotable, Aniplex, Shueisha, Aniplex of Americ...
# 2  MADHOUSE, VAP, Viz Media, Nippon Television Ne...
# 3  Toho, MAPPA, Shueisha, Sumzap, Mainichi Broadc...
# 4  bones, Dentsu, Mainichi Broadcasting System, T...

# %%
import requests

QUERY = """
query {
  Page(page: 1, perPage: 1) {
    pageInfo {
      total
    }
    media(type: ANIME, isAdult: false) {
      id
    }
  }
}
"""

resp = requests.post(
    "https://graphql.anilist.co",
    json={"query": QUERY},
    headers={"Content-Type": "application/json"}
)

print(resp.json())
# Out:
# {'data': {'Page': {'pageInfo': {'total': 20040}, 'media': [{'id': 1}]}}}

# %%
import json
import time
import random
import requests

ENDPOINT = "https://graphql.anilist.co"

# 상위 10,000개용 경량 쿼리 (studios, staff 포함)
QUERY = """
query ($page: Int!, $perPage: Int!) {
  Page(page: $page, perPage: $perPage) {
    pageInfo {
      total
      hasNextPage
    }
    media(
      type: ANIME
      isAdult: false
      sort: POPULARITY_DESC
      format_not_in: [MUSIC]
      status_not_in: [CANCELLED]
    ) {
      id
      title { romaji english native }
      format
      status
      season
      seasonYear
      episodes
      duration
      averageScore
      meanScore
      popularity
      favourites
      genres
      tags { name }

      studios {
        nodes { name }
        edges { isMain }
      }
      staff {
        nodes { name { full } primaryOccupations }
        edges { role }
      }
    }
  }
}
"""


def fetch_page(page: int, per_page: int, max_retries: int = 5) -> dict:
    """
    AniList Page 한 페이지를 가져오는 함수.
    - 429 Too Many Requests 발생 시 Retry-After 헤더를 참고해 대기 후 재시도
    - 그 외 네트워크 에러는 지수적 대기로 몇 번 재시도 후 실패
    """
    for attempt in range(max_retries):
        try:
            resp = requests.post(
                ENDPOINT,
                json={"query": QUERY, "variables": {"page": page, "perPage": per_page}},
                headers={"Content-Type": "application/json", "Accept": "application/json"},
                timeout=30,
            )

            # 정상 응답
            if resp.status_code == 200:
                data = resp.json()
                if "data" not in data:
                    raise RuntimeError(f"Unexpected response format: {data}")
                return data["data"]["Page"]

            # 레이트 리밋 초과
            if resp.status_code == 429:
                retry_after = resp.headers.get("Retry-After")
                if retry_after is not None:
                    wait_time = float(retry_after)
                else:
                    wait_time = 4.0
                wait_time += random.uniform(0.1, 0.5)
                print(f"[429] Too Many Requests, {wait_time:.1f}초 대기 후 재시도...")
                time.sleep(wait_time)
                continue

            # 그 외 HTTP 에러
            print(f"[HTTP {resp.status_code}] 응답 에러:")
            print(resp.text)
            resp.raise_for_status()

        except requests.exceptions.RequestException as e:
            # 네트워크 계열 예외: 약간씩 대기 시간 늘려가며 재시도
            backoff = 2 + attempt * 1.5
            print(f"[오류] 요청 중 예외 발생 (시도 {attempt + 1}/{max_retries}): {e}")
            print(f"{backoff:.1f}초 대기 후 재시도...")
            time.sleep(backoff)

    raise RuntimeError("최대 재시도 횟수 초과로 실패했습니다.")


def fetch_top_json(out_path: str = "anilist_top10000.json") -> None:
    per_page = 50
    max_items = 10000
    items: list[dict] = []

    page = 1

    while len(items) < max_items:
        print(f"Fetching page {page} (현재 수집 개수: {len(items)}) ...")

        page_data = fetch_page(page, per_page)
        media_list = page_data.get("media") or []
        items.extend(media_list)

        page_info = page_data.get("pageInfo") or {}
        has_next = page_info.get("hasNextPage", False)

        if not has_next:
            print("더 가져올 페이지가 없어 중단합니다.")
            break

        page += 1
        # 기본적인 템포 제한 (429 대비용, 너무 자주 안 때리게)
        time.sleep(0.8)

        if len(items) >= max_items:
            break

    # 10,000개로 자르기
    items = items[:max_items]
    print(f"총 {len(items)}개 작품 수집 완료. 파일로 저장합니다...")

    with open(out_path, "w", encoding="utf-8") as f:
        json.dump(items, f, ensure_ascii=False, indent=2)

    print(f"Saved {len(items)} items to {out_path}")


if __name__ == "__main__":
    fetch_top_json()
# Out:
# Fetching page 1 (현재 수집 개수: 0) ...
# Fetching page 2 (현재 수집 개수: 50) ...
# Fetching page 3 (현재 수집 개수: 100) ...
# Fetching page 4 (현재 수집 개수: 150) ...
# Fetching page 5 (현재 수집 개수: 200) ...
# Fetching page 6 (현재 수집 개수: 250) ...
# Fetching page 7 (현재 수집 개수: 300) ...
# Fetching page 8 (현재 수집 개수: 350) ...
# Fetching page 9 (현재 수집 개수: 400) ...
# Fetching page 10 (현재 수집 개수: 450) ...
# Fetching page 11 (현재 수집 개수: 500) ...
# Fetching page 12 (현재 수집 개수: 550) ...
# Fetching page 13 (현재 수집 개수: 600) ...
# Fetching page 14 (현재 수집 개수: 650) ...
# Fetching page 15 (현재 수집 개수: 700) ...
# Fetching page 16 (현재 수집 개수: 750) ...
# Fetching page 17 (현재 수집 개수: 800) ...
# Fetching page 18 (현재 수집 개수: 850) ...
# Fetching page 19 (현재 수집 개수: 900) ...
# Fetching page 20 (현재 수집 개수: 950) ...
# Fetching page 21 (현재 수집 개수: 1000) ...
# Fetching page 22 (현재 수집 개수: 1050) ...
# Fetching page 23 (현재 수집 개수: 1100) ...
# Fetching page 24 (현재 수집 개수: 1150) ...
# Fetching page 25 (현재 수집 개수: 1200) ...
# Fetching page 26 (현재 수집 개수: 1250) ...
# Fetching page 27 (현재 수집 개수: 1300) ...
# Fetching page 28 (현재 수집 개수: 1350) ...
# Fetching page 29 (현재 수집 개수: 1400) ...
# Fetching page 30 (현재 수집 개수: 1450) ...
# Fetching page 31 (현재 수집 개수: 1500) ...
# Fetching page 32 (현재 수집 개수: 1550) ...
# Fetching page 33 (현재 수집 개수: 1600) ...
# Fetching page 34 (현재 수집 개수: 1650) ...
# Fetching page 35 (현재 수집 개수: 1700) ...
# Fetching page 36 (현재 수집 개수: 1750) ...
# Fetching page 37 (현재 수집 개수: 1800) ...
# Fetching page 38 (현재 수집 개수: 1850) ...
# Fetching page 39 (현재 수집 개수: 1900) ...
# Fetching page 40 (현재 수집 개수: 1950) ...
# Fetching page 41 (현재 수집 개수: 2000) ...
# Fetching page 42 (현재 수집 개수: 2050) ...
# Fetching page 43 (현재 수집 개수: 2100) ...
# Fetching page 44 (현재 수집 개수: 2150) ...
# Fetching page 45 (현재 수집 개수: 2200) ...
# Fetching page 46 (현재 수집 개수: 2250) ...
# Fetching page 47 (현재 수집 개수: 2300) ...
# Fetching page 48 (현재 수집 개수: 2350) ...
# Fetching page 49 (현재 수집 개수: 2400) ...
# Fetching page 50 (현재 수집 개수: 2450) ...
# Fetching page 51 (현재 수집 개수: 2500) ...
# Fetching page 52 (현재 수집 개수: 2550) ...
# Fetching page 53 (현재 수집 개수: 2600) ...
# Fetching page 54 (현재 수집 개수: 2650) ...
# Fetching page 55 (현재 수집 개수: 2700) ...
# Fetching page 56 (현재 수집 개수: 2750) ...
# Fetching page 57 (현재 수집 개수: 2800) ...
# Fetching page 58 (현재 수집 개수: 2850) ...
# Fetching page 59 (현재 수집 개수: 2900) ...
# Fetching page 60 (현재 수집 개수: 2950) ...
# Fetching page 61 (현재 수집 개수: 3000) ...
# Fetching page 62 (현재 수집 개수: 3050) ...
# Fetching page 63 (현재 수집 개수: 3100) ...
# Fetching page 64 (현재 수집 개수: 3150) ...
# Fetching page 65 (현재 수집 개수: 3200) ...
# Fetching page 66 (현재 수집 개수: 3250) ...
# Fetching page 67 (현재 수집 개수: 3300) ...
# Fetching page 68 (현재 수집 개수: 3350) ...
# Fetching page 69 (현재 수집 개수: 3400) ...
# Fetching page 70 (현재 수집 개수: 3450) ...
# Fetching page 71 (현재 수집 개수: 3500) ...
# Fetching page 72 (현재 수집 개수: 3550) ...
# Fetching page 73 (현재 수집 개수: 3600) ...
# Fetching page 74 (현재 수집 개수: 3650) ...
# Fetching page 75 (현재 수집 개수: 3700) ...
# Fetching page 76 (현재 수집 개수: 3750) ...
# Fetching page 77 (현재 수집 개수: 3800) ...
# Fetching page 78 (현재 수집 개수: 3850) ...
# Fetching page 79 (현재 수집 개수: 3900) ...
# Fetching page 80 (현재 수집 개수: 3950) ...
# Fetching page 81 (현재 수집 개수: 4000) ...
# Fetching page 82 (현재 수집 개수: 4050) ...
# Fetching page 83 (현재 수집 개수: 4100) ...
# Fetching page 84 (현재 수집 개수: 4150) ...
# Fetching page 85 (현재 수집 개수: 4200) ...
# Fetching page 86 (현재 수집 개수: 4250) ...
# Fetching page 87 (현재 수집 개수: 4300) ...
# Fetching page 88 (현재 수집 개수: 4350) ...
# Fetching page 89 (현재 수집 개수: 4400) ...
# Fetching page 90 (현재 수집 개수: 4450) ...
# Fetching page 91 (현재 수집 개수: 4500) ...
# Fetching page 92 (현재 수집 개수: 4550) ...
# Fetching page 93 (현재 수집 개수: 4600) ...
# Fetching page 94 (현재 수집 개수: 4650) ...
# Fetching page 95 (현재 수집 개수: 4700) ...
# Fetching page 96 (현재 수집 개수: 4750) ...
# Fetching page 97 (현재 수집 개수: 4800) ...
# Fetching page 98 (현재 수집 개수: 4850) ...
# Fetching page 99 (현재 수집 개수: 4900) ...
# Fetching page 100 (현재 수집 개수: 4950) ...
# Fetching page 101 (현재 수집 개수: 5000) ...
# Fetching page 102 (현재 수집 개수: 5050) ...
# Fetching page 103 (현재 수집 개수: 5100) ...
# Fetching page 104 (현재 수집 개수: 5150) ...
# Fetching page 105 (현재 수집 개수: 5200) ...
# Fetching page 106 (현재 수집 개수: 5250) ...
# Fetching page 107 (현재 수집 개수: 5300) ...
# Fetching page 108 (현재 수집 개수: 5350) ...
# Fetching page 109 (현재 수집 개수: 5400) ...
# Fetching page 110 (현재 수집 개수: 5450) ...
# Fetching page 111 (현재 수집 개수: 5500) ...
# Fetching page 112 (현재 수집 개수: 5550) ...
# Fetching page 113 (현재 수집 개수: 5600) ...
# Fetching page 114 (현재 수집 개수: 5650) ...
# Fetching page 115 (현재 수집 개수: 5700) ...
# Fetching page 116 (현재 수집 개수: 5750) ...
# Fetching page 117 (현재 수집 개수: 5800) ...
# Fetching page 118 (현재 수집 개수: 5850) ...
# Fetching page 119 (현재 수집 개수: 5900) ...
# Fetching page 120 (현재 수집 개수: 5950) ...
# Fetching page 121 (현재 수집 개수: 6000) ...
# Fetching page 122 (현재 수집 개수: 6050) ...
# Fetching page 123 (현재 수집 개수: 6100) ...
# Fetching page 124 (현재 수집 개수: 6150) ...
# Fetching page 125 (현재 수집 개수: 6200) ...
# Fetching page 126 (현재 수집 개수: 6250) ...
# Fetching page 127 (현재 수집 개수: 6300) ...
# Fetching page 128 (현재 수집 개수: 6350) ...
# Fetching page 129 (현재 수집 개수: 6400) ...
# Fetching page 130 (현재 수집 개수: 6450) ...
# Fetching page 131 (현재 수집 개수: 6500) ...
# Fetching page 132 (현재 수집 개수: 6550) ...
# Fetching page 133 (현재 수집 개수: 6600) ...
# Fetching page 134 (현재 수집 개수: 6650) ...
# Fetching page 135 (현재 수집 개수: 6700) ...
# Fetching page 136 (현재 수집 개수: 6750) ...
# Fetching page 137 (현재 수집 개수: 6800) ...
# Fetching page 138 (현재 수집 개수: 6850) ...
# Fetching page 139 (현재 수집 개수: 6900) ...
# Fetching page 140 (현재 수집 개수: 6950) ...
# Fetching page 141 (현재 수집 개수: 7000) ...
# Fetching page 142 (현재 수집 개수: 7050) ...
# Fetching page 143 (현재 수집 개수: 7100) ...
# Fetching page 144 (현재 수집 개수: 7150) ...
# Fetching page 145 (현재 수집 개수: 7200) ...
# Fetching page 146 (현재 수집 개수: 7250) ...
# Fetching page 147 (현재 수집 개수: 7300) ...
# Fetching page 148 (현재 수집 개수: 7350) ...
# Fetching page 149 (현재 수집 개수: 7400) ...
# Fetching page 150 (현재 수집 개수: 7450) ...
# Fetching page 151 (현재 수집 개수: 7500) ...
# Fetching page 152 (현재 수집 개수: 7550) ...
# Fetching page 153 (현재 수집 개수: 7600) ...
# Fetching page 154 (현재 수집 개수: 7650) ...
# Fetching page 155 (현재 수집 개수: 7700) ...
# Fetching page 156 (현재 수집 개수: 7750) ...
# Fetching page 157 (현재 수집 개수: 7800) ...
# Fetching page 158 (현재 수집 개수: 7850) ...
# Fetching page 159 (현재 수집 개수: 7900) ...
# Fetching page 160 (현재 수집 개수: 7950) ...
# Fetching page 161 (현재 수집 개수: 8000) ...
# Fetching page 162 (현재 수집 개수: 8050) ...
# Fetching page 163 (현재 수집 개수: 8100) ...
# Fetching page 164 (현재 수집 개수: 8150) ...
# Fetching page 165 (현재 수집 개수: 8200) ...
# Fetching page 166 (현재 수집 개수: 8250) ...
# Fetching page 167 (현재 수집 개수: 8300) ...
# Fetching page 168 (현재 수집 개수: 8350) ...
# Fetching page 169 (현재 수집 개수: 8400) ...
# Fetching page 170 (현재 수집 개수: 8450) ...
# Fetching page 171 (현재 수집 개수: 8500) ...
# Fetching page 172 (현재 수집 개수: 8550) ...
# Fetching page 173 (현재 수집 개수: 8600) ...
# Fetching page 174 (현재 수집 개수: 8650) ...
# Fetching page 175 (현재 수집 개수: 8700) ...
# Fetching page 176 (현재 수집 개수: 8750) ...
# Fetching page 177 (현재 수집 개수: 8800) ...
# Fetching page 178 (현재 수집 개수: 8850) ...
# Fetching page 179 (현재 수집 개수: 8900) ...
# Fetching page 180 (현재 수집 개수: 8950) ...
# Fetching page 181 (현재 수집 개수: 9000) ...
# Fetching page 182 (현재 수집 개수: 9050) ...
# Fetching page 183 (현재 수집 개수: 9100) ...
# Fetching page 184 (현재 수집 개수: 9150) ...
# Fetching page 185 (현재 수집 개수: 9200) ...
# Fetching page 186 (현재 수집 개수: 9250) ...
# Fetching page 187 (현재 수집 개수: 9300) ...
# Fetching page 188 (현재 수집 개수: 9350) ...
# Fetching page 189 (현재 수집 개수: 9400) ...
# Fetching page 190 (현재 수집 개수: 9450) ...
# Fetching page 191 (현재 수집 개수: 9500) ...
# Fetching page 192 (현재 수집 개수: 9550) ...
# Fetching page 193 (현재 수집 개수: 9600) ...
# Fetching page 194 (현재 수집 개수: 9650) ...
# Fetching page 195 (현재 수집 개수: 9700) ...
# Fetching page 196 (현재 수집 개수: 9750) ...
# Fetching page 197 (현재 수집 개수: 9800) ...
# Fetching page 198 (현재 수집 개수: 9850) ...
# Fetching page 199 (현재 수집 개수: 9900) ...
# Fetching page 200 (현재 수집 개수: 9950) ...
# 총 10000개 작품 수집 완료. 파일로 저장합니다...
# Saved 10000 items to anilist_top10000.json
